# %%
# !git clone https://git.code.sf.net/p/prostack/code prostack-code
# Out:
# Cloning into 'prostack-code'...
# remote: Enumerating objects: 7094, done.
# remote: Counting objects: 100% (7094/7094), done.
# remote: Compressing objects: 100% (3176/3176), done.
# remote: Total 7094 (delta 5364), reused 5068 (delta 3690)
# Receiving objects: 100% (7094/7094), 58.23 MiB | 12.57 MiB/s, done.
# Resolving deltas: 100% (5364/5364), done.
# Updating files: 100% (1483/1483), done.

# %%
# !apt-get install glib2.0-dev automake autoconf libtool intltool pkg-config libgtk-3-dev libfftw3-dev libgts-dev libgsl-dev libsoup2.4-dev sqlite3-tools libsqlite3-dev sqlite3 imagemagick exim4-base
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libglib2.0-dev-bin' for regex 'glib2.0-dev'
# Note, selecting 'libglib2.0-dev' for regex 'glib2.0-dev'
# autoconf is already the newest version (2.71-2).
# autoconf set to manually installed.
# automake is already the newest version (1:1.16.5-1.3).
# automake set to manually installed.
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# libsqlite3-dev is already the newest version (3.37.2-2ubuntu0.3).
# libsqlite3-dev set to manually installed.
# The following additional packages will be installed:
#   bsd-mailx exim4-config exim4-daemon-heavy fonts-droid-fallback fonts-noto-mono fonts-urw-base35
#   gettext gettext-base ghostscript gir1.2-atk-1.0 gir1.2-atspi-2.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 gir1.2-soup-2.4
# ...

# %%
# %cd prostack-code/
# Out:
# /content/prostack-code

# %%
# !git checkout develop
# Out:
# Branch 'develop' set up to track remote branch 'develop' from 'origin'.
# Switched to a new branch 'develop'

# %%
# %cd prostack/
# Out:
# /content/prostack-code/prostack

# %%
# !autoreconf -fi
# Out:
# libtoolize: putting auxiliary files in '.'.
# libtoolize: copying file './ltmain.sh'
# libtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4'.
# libtoolize: copying file 'm4/libtool.m4'
# libtoolize: copying file 'm4/ltoptions.m4'
# libtoolize: copying file 'm4/ltsugar.m4'
# libtoolize: copying file 'm4/ltversion.m4'
# libtoolize: copying file 'm4/lt~obsolete.m4'
# configure.ac:8: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.
# ./lib/autoconf/general.m4:2434: AC_DIAGNOSE is expanded from...
# aclocal.m4:1225: AM_INIT_AUTOMAKE is expanded from...
# configure.ac:8: the top level
# configure.ac:9: warning: 'AM_CONFIG_HEADER': this macro is obsolete.
# configure.ac:9: You should use the 'AC_CONFIG_HEADERS' macro instead.
# ./lib/autoconf/general.m4:2434: AC_DIAGNOSE is expanded from...
# aclocal.m4:1577: AM_CONFIG_HEADER is expanded from...
# configure.ac:9: the top level
# configure.ac:15: warning: 'AM_PROG_CC_STDC': this macro is obsolete.
# ...

# %%
# !./configure
# Out:
# checking whether make supports nested variables... yes
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking whether make supports the include directive... yes (GNU style)
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to enable C11 features... none needed
# checking whether gcc understands -c and -o together... yes
# ...

# %%
# !make
# Out:
# Streaming output truncated to the last 5000 lines.
#       |         ^~~~~~
# ./CharPixel.h:34:9: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
#    34 |         uint32 column;
#       |         ^~~~~~
# ./CharPixel.h:42:1: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
#    42 | CharPixel*NewCharPixel(uint32 row, uint32 column, unsigned char intensity);
#       | ^~~~~~~~~
# ./CharPixel.h:42:1: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
# ./CharPixel.h:48:9: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
#    48 |         uint32 size;
#       |         ^~~~~~
# ./CharPixel.h:84:1: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
#    84 | Centroid*NewCentroid(Blob*b, uint32 columns, uint32 rows);
#       | ^~~~~~~~
# ./CharPixel.h:84:1: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
# ./CharPixel.h:101:1: warning: ‘uint32’ is deprecated [-Wdeprecated-declarations]
# ...

# %%
# !make install
# Out:
# Making install in door/src
# make[1]: Entering directory '/content/prostack-code/prostack/door/src'
# make[2]: Entering directory '/content/prostack-code/prostack/door/src'
#  /usr/bin/mkdir -p '/usr/local/lib'
#  /bin/bash ../../libtool   --mode=install /usr/bin/install -c   libdoor.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libdoor.so.0.0.4 /usr/local/lib/libdoor.so.0.0.4
# libtool: install: (cd /usr/local/lib && { ln -s -f libdoor.so.0.0.4 libdoor.so.0 || { rm -f libdoor.so.0 && ln -s libdoor.so.0.0.4 libdoor.so.0; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libdoor.so.0.0.4 libdoor.so || { rm -f libdoor.so && ln -s libdoor.so.0.0.4 libdoor.so; }; })
# libtool: install: /usr/bin/install -c .libs/libdoor.lai /usr/local/lib/libdoor.la
# libtool: install: /usr/bin/install -c .libs/libdoor.a /usr/local/lib/libdoor.a
# libtool: install: chmod 644 /usr/local/lib/libdoor.a
# libtool: install: ranlib /usr/local/lib/libdoor.a
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# %env LD_LIBRARY_PATH=/usr/local/lib:$LD_LIBRARY_PATH
# Out:
# env: LD_LIBRARY_PATH=/usr/local/lib:$LD_LIBRARY_PATH

# %%
# !git clone https://gitlab.com/tima1337/colonies_tracking_release.git
# Out:
# Cloning into 'colonies_tracking_release'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 29 (delta 0), reused 0 (delta 0), pack-reused 28 (from 1)
# Receiving objects: 100% (29/29), 210.94 KiB | 8.11 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip /content/colonies_tracking_release/Registration_and_Tracking.zip -d colonies_tracking_base
# Out:
# Archive:  /content/colonies_tracking_release/Registration_and_Tracking.zip
#   inflating: colonies_tracking_base/CoreTrackingAPI.py
#   inflating: colonies_tracking_base/ImageProcessing.py
#   inflating: colonies_tracking_base/ImageRegistration.py
#   inflating: colonies_tracking_base/ImageRegistrationCore.py

# %%
# !mkdir /content/work_trk

# %%
# !pip install laptrack napari
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 40.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 42.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 kB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 27.9 MB/s eta 0:00:00
# ...

# %%
# !tar jxf /content/drive/MyDrive/col2.tbz

# %%
# !mv /content/20230313T133214_/Image/W0001F0003 /content/work_input

# %%
# !mkdir /content/work_output

# %%
# !rm -f /content/work_output/*

# %%
# !unzip /content/colonies_tracking_release/Detection.zip -d Detection
# Out:
# Archive:  /content/colonies_tracking_release/Detection.zip
#   inflating: Detection/annotate.txt
#   inflating: Detection/cvlib.py
#   inflating: Detection/files_manager.py
#   inflating: Detection/result.py

# %%
# %cd /content/
# Out:
# /content

# %%
# %mkdir results

# %%
# %export PYTHONPATH=/content/Detection
# Out:
# UsageError: Line magic function `%export` not found.

# %%
# !python3 Detection/result.py
# Out:
# /content/work_input/W0001F0003T0001Z001C1.tif
# results/strel_output__6xkdft.txt
# results/strel_output__3fdcxj.txt
# results/strel_output__7zhgmu.txt
# results/strel_output__1gbrpn.txt
# results/convert_output__0pgijt.tif
# convert-im6.q16: Unknown field with tag 33434 (0x829a) encountered. `TIFFReadDirectory' @ warning/tiff.c/TIFFWarnings/985.
# convert-im6.q16: Unknown field with tag 36864 (0x9000) encountered. `TIFFReadDirectory' @ warning/tiff.c/TIFFWarnings/985.
# convert-im6.q16: Unknown field with tag 36867 (0x9003) encountered. `TIFFReadDirectory' @ warning/tiff.c/TIFFWarnings/985.
# convert-im6.q16: Unknown field with tag 36868 (0x9004) encountered. `TIFFReadDirectory' @ warning/tiff.c/TIFFWarnings/985.
# convert-im6.q16: Unknown field with tag 37500 (0x927c) encountered. `TIFFReadDirectory' @ warning/tiff.c/TIFFWarnings/985.
# convert-im6.q16: Unknown field with tag 41486 (0xa20e) encountered. `TIFFReadDirectory' @ warning/tiff.c/TIFFWarnings/985.
# ...

# %%
# !python3 /content/colonies_tracking_base/ColoniesTracker/ImageRegistrationCore.py \
/content/work_input \
/content/work_output \
tag_sym="11,15" \
last_num=-1 \
viewer=OFF \
features_cnt=15000 \
N_CORES=4 \
parallel=OFF \
reg_algo=FFT
# Out:
# Размер директории:  96
# Этот скрипт называется:  /content/colonies_tracking_base/ColoniesTracker/ImageRegistrationCore.py
# Путь к директории с данными:  /content/work_input
# Путь к директории для сохранения данных:  /content/work_output
# Количество фреймов в директории:  96
# Viewer:  OFF
# Количество ключевых точек:  15000
# tag sym:  11,15
# last num: -1
# Использование параллельной регистрации изображений: OFF
# Количество ядер для параллельной регистрации изображений: 4
# Алгоритм регистрации изображений: FFT
# ...

# %%
# !python3 /content/colonies_tracking_base/ColoniesTracker/CoreTrackingAPI.py \
/content/work_output \
/content/work_trk \
file_mask="_tab.csv" \
offset=10 \
max_dist_param=100 \
points_cnt=10 \
max_gap=2 \
sq_lower_bound=9999 \
sq_upper_bound=49999 \
bkg_img=/content/work_output/W0001F0003T0001Z001C1_movl.tif \
tag_sym="11,15" \
napari_viewer="OFF" \
custom_offset_mode="OFF" \
matplot_lib="ON" \
split_merge=False \
min_track_len=15 \
shifts_path=/content/work_output.txt \
save_image_path=/content/work_tracks.png
# Out:
# Размер директории:  0
# 11,15
# 1
# 1
# Этот скрипт называется:  /content/colonies_tracking_base/ColoniesTracker/CoreTrackingAPI.py
# Путь к директории с данными:  /content/work_output
# Маска файла с данными:  _tab.csv
# Количество точек:  10
# Количество кадров(const):  96
# Интервал сдвига: (-10, 10)
# Максимальное расстояние:  100
# Максимальное количество кадров для пропуска: 2
# NapariViewer:  OFF
# CustomOffsetMode:  OFF
# Нижняя и верхняя границы для площади колоний молекул: 9999 49999
# Отрисовка слияний и разделений: False
# Минимальная длина трека при отрисовке: 15
# Путь к текстовому файлу со сдвигами: /content/work_output.txt
# ...

# %%
# !tar jcf output_arch.tbz work_output work_trk work_output.txt work_tracks.png

# %%
# !cp output_arch.tbz /content/drive/MyDrive
